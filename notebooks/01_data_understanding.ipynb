# %%
print("Hello")
# Out:
# Hello

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.0 MB 7.5 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/8.0 MB 7.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.0 MB 7.3 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 7.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.0 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 7.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    - -------------------------------------- 1.3/36.5 MB 6.7 MB/s eta 0:00:06
#    --- ------------------------------------ 2.9/36.5 MB 7.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.5/36.5 MB 7.3 MB/s eta 0:00:05
# ...

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.2 MB 7.0 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/8.2 MB 7.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.5/8.2 MB 7.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.2 MB 7.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.2 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 7.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------------------------- ------------- 1.6/2.3 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 7.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.3/7.1 MB 7.4 MB/s eta 0:00:01
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\sures\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe

# %%
# !{sys.executable} -m pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1
# [notice] To update, run: C:\Users\sures\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv("E:/personal document/placement program/student performance project/data/student-mat.csv", sep=';')

print("Shape:", df.shape)
df.head()
df.info()
df.describe()
import matplotlib.pyplot as plt

df['G3'].hist()
plt.show()
df.isnull().sum()
df.to_csv("../data/clean_student_data.csv", index=False)
import matplotlib.pyplot as plt

plt.scatter(df['studytime'], df['G3'])
plt.xlabel("Study Time")
plt.ylabel("Final Grade")
plt.show()
df['pass'] = df['G3'].apply(lambda x: 1 if x >= 10 else 0)

df['pass'].value_counts()
df.to_csv("../data/final_student_data.csv", index=False)
# Out:
# Shape: (395, 33)
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    str
#  1   sex         395 non-null    str
#  2   age         395 non-null    int64
#  3   address     395 non-null    str
#  4   famsize     395 non-null    str
#  5   Pstatus     395 non-null    str
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    str
#  9   Fjob        395 non-null    str
#  10  reason      395 non-null    str
#  11  guardian    395 non-null    str
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    str
#  16  famsup      395 non-null    str
#  17  paid        395 non-null    str
#  18  activities  395 non-null    str
#  19  nursery     395 non-null    str
# ...
